# %%
pip install matplotlib

# %%
import random
import random
X=[]
Y=[]
[X.append(random.randint(0,25))for _ in range (15)]
[Y.append(random.randint(0,25))for _ in range (15)]

print(X)
print(Y)
# Out:
# [25, 17, 1, 15, 1, 5, 17, 14, 8, 11, 24, 22, 7, 13, 13]
# [3, 9, 5, 13, 19, 15, 16, 23, 11, 2, 3, 5, 5, 10, 6]

# %%
from matplotlib import pyplot as plt
plt.plot(X,Y)

# %%
plt.scatter(X,Y)
