# %%
def quiz_game():
    # List of questions, options, and correct answers
    questions = [
        {
            "question": "Who was the first Prime Minister of India?",
            "options": ["A. Indira Gandhi", "B. Narendra Modi", "C. Jawaharlal Nehru", "D. Rajiv Gandhi"],
            "answer": "C"
        },
        {
            "question": "What is the capital city of India?",
            "options": ["A. New Delhi", "B. Mumbai", "C. Kolkata", "D. Chennai"],
            "answer": "A"
        },
        {
            "question": "Which state is also known as the 'Fruit Bowl' of India?",
            "options": ["A. Jammu & Kashmir", "B. Himachal Pradesh", "C. Assam", "D. Meghalaya"],
            "answer": "B"
        },
        {
            "question": "Who is Sachin Tendulkar?",
            "options": ["A. Indian Hockey player", "B. Indian Cricketer", "C.Indian Kabbadi player", "D. Indian Marathon Runner"],
            "answer": "B"
        },
        {
            "question": "who discovered India?",
            "options": ["A. Vasco da Gama", "B. Christopher Columbus", "C. James Cook", "D. Willem Janszoon"],
            "answer": "A"
        },
        {
            "question": "Who is popularly known as the “Iron Man” of India??",
            "options": ["A. Lal Bahadur Shastri", "B. Sardar Vallabh Bhai Patel ", "C. Mahatma Gandhi ", "D. Dr.B.RAmbedkar "],
            "answer": "B"
        },
        {
            "question": "Which is the national sport of India??",
            "options": ["A. Cricket", "B. Hockey", "C. Kabaddi", "D. Football "],
            "answer": "B"
        },
        {
            "question":"Which place in India is also known as the 'Land of Rising Sun'?",
            "options": ["A. Sikkim ", "B. Arunachal Pradesh ", "C. Karnataka ", "D. Gujarat "],
            "answer": "B"
        },
        {
            "question": "Who is the current President of India?",
            "options": ["A. Ram Nath Kovind", "B. Pranab Mukherjee", "C. A. P. J. Abdul Kalam", "D. Pratibha Patil"],
            "answer": "A"
        },
        {
            "question": "Where is Taj Mahal located in India??",
            "options": ["A. New Delhi", "B. Kolkata ", "C.Agra ", "D. Lucknow"],
            "answer": "C"
        }
    ]

    total_score = 0  

    
    for i, question in enumerate(questions, start=1):
        print(f"Question {i}: {question['question']}")
        for option in question['options']:
            print(option)

        
        your_answer = input("Enter answer (A/B/C/D): ").strip().upper()

        match your_answer:
            case answer if answer == question['answer']:
                print("Correct!")
                total_score += 10  
            case _:
                print(f"Wrong! The correct answer is {question['answer']}.")

    # Final score
    print(f"Your total score is {total_score} out of {len(questions) * 10}.")

# Run the quiz game
quiz_game()
# Out:
# Question 1: Who was the first Prime Minister of India?
# A. Indira Gandhi
# B. Narendra Modi
# C. Jawaharlal Nehru
# D. Rajiv Gandhi
# Correct!
# Question 2: What is the capital city of India?
# A. New Delhi
# B. Mumbai
# C. Kolkata
# D. Chennai
# Correct!
# Question 3: Which state is also known as the 'Fruit Bowl' of India?
# A. Jammu & Kashmir
# B. Himachal Pradesh
# C. Assam
# D. Meghalaya
# Correct!
# Question 4: Who is Sachin Tendulkar?
# A. Indian Hockey player
# B. Indian Cricketer
# C.Indian Kabbadi player
# D. Indian Marathon Runner
# Correct!
# Question 5: who discovered India?
# A. Vasco da Gama
# B. Christopher Columbus
# C. James Cook
# D. Willem Janszoon
# Correct!
# Question 6: Who is popularly known as the “Iron Man” of India??
# A. Lal Bahadur Shastri
# B. Sardar Vallabh Bhai Patel
# C. Mahatma Gandhi
# D. Dr.B.RAmbedkar
# Correct!
# Question 7: Which is the national sport of India??
# A. Cricket
# B. Hockey
# C. Kabaddi
# D. Football
# Correct!
# ...
